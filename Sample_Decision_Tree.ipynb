# %% [markdown]
# <a href="https://colab.research.google.com/github/Harish-Arun/ML-Practice/blob/main/Sample_Decision_Tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn import datasets

# %%
iris=datasets.load_iris()
X=iris.data
Y=iris.target

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y)

# %%
from sklearn.tree import DecisionTreeClassifier

DTC=DecisionTreeClassifier(max_leaf_nodes=3,random_state=0)
DTC.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=3, random_state=0)

# %%
from sklearn import tree
tree.plot_tree(DTC)
# Out:
# [Text(0.4, 0.8333333333333334, 'x[3] <= 0.8\ngini = 0.665\nsamples = 112\nvalue = [41, 37, 34]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.6, 0.5, 'x[2] <= 4.75\ngini = 0.499\nsamples = 71\nvalue = [0, 37, 34]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.149\nsamples = 37\nvalue = [0, 3, 34]')]

# %%
pred=DTC.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
print("Accuracy Scores ",accuracy_score(Y_test,pred))
print("Classification Report\n",classification_report(Y_test,pred))
print("Confusion Matrix\n",confusion_matrix(Y_test,pred))
# Out:
# Accuracy Scores  0.8947368421052632
# Classification Report
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       0.91      0.77      0.83        13
#            2       0.83      0.94      0.88        16
#
#     accuracy                           0.89        38
#    macro avg       0.91      0.90      0.91        38
# weighted avg       0.90      0.89      0.89        38
#
# Confusion Matrix
#  [[ 9  0  0]
#  [ 0 10  3]
#  [ 0  1 15]]
